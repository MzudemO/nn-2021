# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams.update({'font.size':20})

run_1 = np.array([1.0000,
0.8706,
0.7944,
0.6448,
0.6845,
0.4490,
0.6913,
0.5287,
0.5003,
0.4515])

run_2 = np.array([0.7515,
0.3874,
0.4966,
0.4848,
0.6023,
0.5052,
0.5491,
0.4682,
0.6145,
0.4989])

run_3 = np.array([0.6337,
0.5314,
0.3248,
0.5483,
0.5496,
0.4335,
0.4039,
0.4333,
0.3768,
0.3823])

maxs = [max(r1, r2, r3) for r1, r2, r3 in zip(run_1, run_2, run_3)]
mins = [min(r1, r2, r3) for r1, r2, r3 in zip(run_1, run_2, run_3)]

plt.figure(figsize=(10,10))
# plt.plot(np.arange(0, 10, 1), run_1, label="Run 1", linestyle="dashed")
# plt.plot(np.arange(0, 10, 1), run_2, label="Run 2", linestyle="dashed")
# plt.plot(np.arange(0, 10, 1), run_3, label="Run 3", linestyle="dashed")
# plt.fill_between(np.arange(0, 10, 1), run_1, run_2, alpha=0.1, color="blue")
# plt.fill_between(np.arange(0, 10, 1), run_1, run_3, alpha=0.1, color="blue")
# plt.fill_between(np.arange(0, 10, 1), run_2, run_3, alpha=0.1, color="blue")
# plt.fill_between(np.arange(0, 10, 1), mins, maxs, alpha=0.2)
plt.vlines(np.arange(1, 11, 1), mins, maxs)
avg = (run_1 + run_2 + run_3) / 3
plt.plot(np.arange(1, 11, 1), avg, label="Average", marker="o", color="orange", markersize=12)
plt.legend()
plt.xticks(np.arange(1, 11, 1))
plt.xlabel("# of digits so far")
plt.ylabel("Evaluation Accuracy")
plt.title("Average Evaluation Accuracy during Training")
plt.show()

# %%
run_2 = np.array([0.0000,
-0.0713,
-0.2500,
-0.1577,
-0.1447,
-0.0500,
-0.0762,
0.0529,
-0.1177,
-0.0195])

run_3 = np.array([0.0000,
-0.1745,
0.0690,
-0.1599,
-0.2210,
-0.1143,
-0.0966,
-0.0349,
0.0579,
0.0892])

run_1 = np.array([0.0000,
0.2578,
0.1174,
0.1282,
0.1050,
0.2887,
-0.0013,
0.1710,
0.1515,
0.1233])

plt.figure(figsize=(10,10))
# plt.plot(np.arange(0, 10, 1), run_2, label="Run 2")
# plt.plot(np.arange(0, 10, 1), run_3, label="Run 3")
# plt.plot(np.arange(0, 10, 1), run_1, label="Run 1")
# avg = (run_1 + run_2 + run_3) / 3
# plt.plot(np.arange(0, 10, 1), avg, label="Average")
maxs = [max(r1, r2, r3) for r1, r2, r3 in zip(run_1, run_2, run_3)]
mins = [min(r1, r2, r3) for r1, r2, r3 in zip(run_1, run_2, run_3)]

plt.figure(figsize=(10,10))
# plt.plot(np.arange(0, 10, 1), run_1, label="Run 1", linestyle="dashed")
# plt.plot(np.arange(0, 10, 1), run_2, label="Run 2", linestyle="dashed")
# plt.plot(np.arange(0, 10, 1), run_3, label="Run 3", linestyle="dashed")
# plt.fill_between(np.arange(0, 10, 1), run_1, run_2, alpha=0.1, color="blue")
# plt.fill_between(np.arange(0, 10, 1), run_1, run_3, alpha=0.1, color="blue")
# plt.fill_between(np.arange(0, 10, 1), run_2, run_3, alpha=0.1, color="blue")
# plt.fill_between(np.arange(0, 10, 1), mins, maxs, alpha=0.2)
plt.vlines(np.arange(1, 11, 1), mins, maxs)
avg = (run_1 + run_2 + run_3) / 3
plt.plot(np.arange(1, 11, 1), avg, label="Average", marker="o", color="orange", markersize=12)
plt.legend()
plt.xticks(np.arange(1, 11, 1))
plt.xlabel("# of digits so far")
plt.ylabel("Evaluation Forgetting")
plt.title("Average Evaluation Forgetting during Training")
plt.show()

# %%
run_2 = np.array([0.7515,
0.8228,
0.7871,
0.7851,
0.7851,
0.4941,
0.6218,
0.0109,
0.8277,
0.3960])

run_3 = np.array([0.6337,
0.8082,
0.6918,
0.7551,
0.7602,
0.7694,
0.3449,
0.4531,
0.2010,
0.2051])

run_1 = np.array([1.0000,
0.7422,
0.8278,
0.7025,
0.6493,
0.6263,
0.8257,
0.8528,
0.7505,
0.7453])

plt.figure(figsize=(10,10))
# plt.plot(np.arange(0, 10, 1), run_2, label="Run 2")
# plt.plot(np.arange(0, 10, 1), run_3, label="Run 3")
# plt.plot(np.arange(0, 10, 1), run_1, label="Run 1")
# avg = (run_1 + run_2 + run_3) / 3
# plt.plot(np.arange(0, 10, 1), avg, label="Average")
maxs = [max(r1, r2, r3) for r1, r2, r3 in zip(run_1, run_2, run_3)]
mins = [min(r1, r2, r3) for r1, r2, r3 in zip(run_1, run_2, run_3)]

plt.figure(figsize=(10,10))
# plt.plot(np.arange(0, 10, 1), run_1, label="Run 1", linestyle="dashed")
# plt.plot(np.arange(0, 10, 1), run_2, label="Run 2", linestyle="dashed")
# plt.plot(np.arange(0, 10, 1), run_3, label="Run 3", linestyle="dashed")
# plt.fill_between(np.arange(0, 10, 1), run_1, run_2, alpha=0.1, color="blue")
# plt.fill_between(np.arange(0, 10, 1), run_1, run_3, alpha=0.1, color="blue")
# plt.fill_between(np.arange(0, 10, 1), run_2, run_3, alpha=0.1, color="blue")
# plt.fill_between(np.arange(0, 10, 1), mins, maxs, alpha=0.2)
plt.vlines(np.arange(1, 11, 1), mins, maxs)
avg = (run_1 + run_2 + run_3) / 3
plt.plot(np.arange(1, 11, 1), avg, label="Average", marker="o", color="orange", markersize=12)
plt.legend()
plt.xticks(np.arange(1, 11, 1))
plt.xlabel("# of digits so far")
plt.ylabel("Evaluation Accuracy")
plt.title("Evaluation Accuracy of First Digit during Training")
plt.show()

# %%
run_2 = np.array([0.7550,
0.7219,
0.2759,
0.3204,
0.9692,
0.2777,
0.7165,
0.7537,
0.5879,
0.2714])

run_3 = np.array([0.6267,
0.3575,
0.4409,
0.5921,
0.2376,
0.2527,
0.2055,
0.9535,
0.7175,
0.7689])

run_1 = np.array([0.9998,
0.9624,
0.5166,
0.1880,
0.4823,
0.6326,
0.6088,
0.4747,
0.0601,
0.1880])

plt.figure(figsize=(10,10))
# plt.plot(np.arange(0, 10, 1), run_2, label="Run 2")
# plt.plot(np.arange(0, 10, 1), run_3, label="Run 3")
# plt.plot(np.arange(0, 10, 1), run_1, label="Run 1")
# avg = (run_1 + run_2 + run_3) / 3
# plt.plot(np.arange(0, 10, 1), avg, label="Average")
maxs = [max(r1, r2, r3) for r1, r2, r3 in zip(run_1, run_2, run_3)]
mins = [min(r1, r2, r3) for r1, r2, r3 in zip(run_1, run_2, run_3)]

plt.figure(figsize=(10,10))
# plt.plot(np.arange(0, 10, 1), run_1, label="Run 1", linestyle="dashed")
# plt.plot(np.arange(0, 10, 1), run_2, label="Run 2", linestyle="dashed")
# plt.plot(np.arange(0, 10, 1), run_3, label="Run 3", linestyle="dashed")
# plt.fill_between(np.arange(0, 10, 1), run_1, run_2, alpha=0.1, color="blue")
# plt.fill_between(np.arange(0, 10, 1), run_1, run_3, alpha=0.1, color="blue")
# plt.fill_between(np.arange(0, 10, 1), run_2, run_3, alpha=0.1, color="blue")
# plt.fill_between(np.arange(0, 10, 1), mins, maxs, alpha=0.2)
plt.vlines(np.arange(1, 11, 1), mins, maxs)
avg = (run_1 + run_2 + run_3) / 3
plt.plot(np.arange(1, 11, 1), avg, label="Average", marker="o", color="orange", markersize=12)
plt.legend()
plt.xticks(np.arange(1, 11, 1))
plt.xlabel("# of digits so far")
plt.ylabel("Training Accuracy")
plt.title("Average Training Accuracy")
plt.show()

# %%
class_order = np.arange(0, 10, 1)

run_1 = np.array([0.6088, 0.6326, 0.4747, 0.5166, 0.0601, 0.1880, 0.9998, 0.1880, 0.9624, 0.4823])
run_2 = np.array([0.7537, 0.7219, 0.7165, 0.7550, 0.2759, 0.2714, 0.9692, 0.2777, 0.5879, 0.3204])
run_3 = np.array([0.6267, 0.7689, 0.5921, 0.4409, 0.2376, 0.2055, 0.9535, 0.2527, 0.7175, 0.3575])

avgs = (run_1 + run_2 + run_3) / 3

plt.figure(figsize=(10, 10))
plt.bar(np.arange(0, 10, 1), avgs)
plt.xticks(np.arange(0, 10, 1))
plt.xlabel("Digit")
plt.ylabel("Training Accuracy")
plt.title("Average Training Accuracy for each Class")
plt.show()
